# %%
import pandas as pd
from IPython.display import Markdown

# %%
df = pd.read_spss('ATP W41.sav')

df.describe()
# Out:
#                QKEY   WEIGHT_W41
# count  2.524000e+03  2524.000000
# mean   1.575407e+11     1.000000
# std    8.346360e+10     0.809028
# min    1.003630e+05     0.094035
# 25%    2.015012e+11     0.427967
# 50%    2.018010e+11     0.755901
# 75%    2.018011e+11     1.329694
# max    2.018012e+11     4.509111

# %%
# Out:
# <table>
#     <th>Variable</th><th>Name</th><th>Description</th>
#     <tr>
#         <td><code>NEW_Device_Type_W41</code>
#         <td>None</td>
#         <td>
#     <ul>1 Mobile phone</ul>
# <ul>2 Desktop</ul>
# <ul>3 Tablet</ul>
# </td>
#     </tr>
#     <tr>
#         <td><code>F_LANGUAGE</code>
#         <td>None</td>
#         <td>
#     <ul>1 English</ul>
# <ul>2 Spanish</ul>
# </td>
#     </tr>
#     <tr>
#         <td><code>FORM_W41</code>
#         <td>None</td>
#         <td>
#     <ul>1 Form 1</ul>
# <ul>2 Form 2</ul>
# </td>
#     </tr>
#     <tr>
#         <td><code>OPTIMIST_W41</code>
#         <td>None</td>
#         <td>
#     <ul>1 Somewhat optimistic</ul>
# <ul>2 Somewhat pessimistic</ul>
# <ul>3 Very optimistic</ul>
# <ul>4 Very pessimistic</ul>
# <ul>5 Refused</ul>
# </td>
#     </tr>
#     <tr>
#         <td><code>AVGFAM_W41</code>
#         <td>None</td>
#         <td>
#     <ul>1 Get worse</ul>
# <ul>2 Get better</ul>
# <ul>3 Stay about the same</ul>
# ...
