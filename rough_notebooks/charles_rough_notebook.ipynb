# %%
import pandas as pd

from IPython.display import Markdown

from itertools import combinations

from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression

from prepare import *
from explore import *
from model import *

# %%
df, revert_key, replace_key = wrangle_data()

# %%
obj = run_using_pes_val(df)

# %%
obj.chi2_df.sort_values(by='p_val')
# Out:
#                                               chi2         p_val deg_free  \
# happen_general                          347.637731  4.961200e-72        6
# happen_pub_ed                           284.439932  1.760564e-58        6
# happen_child_f2                         214.463817  3.051666e-41        9
# happen_race                             200.564853  1.438719e-40        6
# happen_health                           196.749151  9.333174e-40        6
# ...                                            ...           ...      ...
# political_party_lean                      7.418408  5.936429e-01        9
# harass_interactions_f1                    9.723741  6.401823e-01       12
# summary_of_political_party_data           4.143776  6.572267e-01        6
# elder_finance_2                           6.381575  8.956392e-01       12
# second_most_responsible_for_workers_f1    7.062409  9.558947e-01       15
#
#                                                                             expected_freq
# happen_general                          [[13.116477272727273, 50.44176136363637, 36.51...
# happen_pub_ed                           [[15.417613636363637, 59.29119318181818, 42.92...
# happen_child_f2                         [[35.66761363636363, 137.1661931818182, 99.296...
# happen_race                             [[65.58238636363636, 252.2088068181818, 182.57...
# happen_health                           [[92.85085227272727, 357.0745738636364, 258.49...
# ...                                                                                   ...
# political_party_lean                    [[7.938920454545454, 30.530539772727273, 22.10...
# harass_interactions_f1                  [[10.009943181818182, 38.49502840909091, 27.86...
# summary_of_political_party_data         [[66.96306818181819, 257.51846590909093, 186.4...
# elder_finance_2                         [[13.806818181818182, 53.09659090909091, 38.43...
# second_most_responsible_for_workers_f1  [[19.099431818181817, 73.4502840909091, 53.171...
#
# [120 rows x 4 columns]

# %%
score_df = pd.DataFrame(columns = ['model_name', 'train_score', 'validate_score'])
tree_list, tree_model_name_list = decision_tree_models(10)

for model, name, in zip(tree_list, tree_model_name_list):
    score_df = test_a_model(obj.X_train_dummies, obj.y_train_dummies,
                           obj.X_validate_dummies, obj.y_validate_dummies,
                           model, name, score_df)

score_df.sort_values(by='validate_score', ascending = False)
# Out:
#               model_name  train_score  validate_score
# 1  decision_tree_depth_4     0.600852        0.531457
# 0  decision_tree_depth_3     0.556108        0.529801
# 2  decision_tree_depth_5     0.624290        0.486755
# 3  decision_tree_depth_6     0.669034        0.483444
# 4  decision_tree_depth_7     0.716619        0.475166
# 6  decision_tree_depth_9     0.793324        0.468543
# 5  decision_tree_depth_8     0.760653        0.466887
