# %% [markdown]
# # Individual Exploration and Analysis of the Data

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Acquire Data

# %%
df = pd.read_spss("ATP W41.sav")

# %%
df.head()
# Out:
#        QKEY NEW_Device_Type_W41 F_LANGUAGE FORM_W41          OPTIMIST_W41  \
# 0  100363.0        Mobile phone    English   Form 1   Somewhat optimistic
# 1  101224.0        Mobile phone    English   Form 1   Somewhat optimistic
# 2  101437.0             Desktop    English   Form 1  Somewhat pessimistic
# 3  102130.0        Mobile phone    English   Form 1   Somewhat optimistic
# 4  103094.0        Mobile phone    English   Form 1   Somewhat optimistic
#
#             AVGFAM_W41                        HAPPENa_W41  \
# 0            Get worse  The U.S. economy will be STRONGER
# 1           Get better  The U.S. economy will be STRONGER
# 2            Get worse    The U.S. economy will be WEAKER
# 3  Stay about the same    The U.S. economy will be WEAKER
# 4  Stay about the same                            Refused
#
#                            HAPPENb_W41                    HAPPENc_W41  \
# 0  Health care will be MORE affordable    Race relations will IMPROVE
# 1  Health care will be LESS affordable    Race relations will IMPROVE
# 2  Health care will be LESS affordable  Race relations will GET WORSE
# 3  Health care will be LESS affordable    Race relations will IMPROVE
# 4  Health care will be LESS affordable                        Refused
#
#                                     HAPPENd_W41  ...   F_PARTY_FINAL  \
# 0  The U.S. will be MORE important in the world  ...        Democrat
# 1  The U.S. will be MORE important in the world  ...      Republican
# 2  The U.S. will be LESS important in the world  ...      Republican
# 3  The U.S. will be LESS important in the world  ...     Independent
# 4  The U.S. will be LESS important in the world  ...  Something else
#
#   F_PARTYLN_FINAL    F_PARTYSUM_FINAL                        F_INCOME  \
# 0             NaN        Dem/Lean Dem  $100,000 to less than $150,000
# 1             NaN        Rep/Lean Rep    $40,000 to less than $50,000
# 2             NaN        Rep/Lean Rep    $10,000 to less than $20,000
# 3         Refused  DK/Refused/No lean                         Refused
# 4         Refused  DK/Refused/No lean    $20,000 to less than $30,000
#
#       F_INCOME_RECODE                                              F_REG  \
# 0            $75,000+  You are ABSOLUTELY CERTAIN that you are regist...
# 1         $30-$74,999  You are ABSOLUTELY CERTAIN that you are regist...
# 2            <$30,000  You are ABSOLUTELY CERTAIN that you are regist...
# 3  Don't know/Refused  You are ABSOLUTELY CERTAIN that you are regist...
# 4            <$30,000  You are NOT registered to vote at your current...
#
#          F_IDEO          F_INTUSER F_VOLSUM WEIGHT_W41
# 0       Liberal      Internet User       No   0.599006
# 1  Conservative      Internet User      Yes   0.292981
# 2  Conservative      Internet User       No   0.418871
# 3      Moderate  Non Internet User      Yes   0.342058
# 4       Liberal      Internet User      Yes   0.329465
#
# [5 rows x 124 columns]

# %%
columns = df.columns.to_list()

# %%
for col in columns:
    print(col)
    print(df[col].value_counts())
    print(" ")
# Out:
# QKEY
# 2.018011e+11    1
# 2.018011e+11    1
# 2.018011e+11    1
# 2.018011e+11    1
# 2.018011e+11    1
#                ..
# 2.015016e+11    1
# 2.018011e+11    1
# 2.018011e+11    1
# 2.018011e+11    1
# 2.018011e+11    1
# Name: QKEY, Length: 2524, dtype: int64
#
# NEW_Device_Type_W41
# Mobile phone    1345
# Desktop          882
# Tablet           297
# Name: NEW_Device_Type_W41, dtype: int64
#
# F_LANGUAGE
# English    2483
# Spanish      41
# Name: F_LANGUAGE, dtype: int64
#
# FORM_W41
# Form 2    1275
# Form 1    1249
# Name: FORM_W41, dtype: int64
#
# OPTIMIST_W41
# Somewhat optimistic     1113
# Somewhat pessimistic     806
# Very pessimistic         306
# Very optimistic          290
# Refused                    9
# Name: OPTIMIST_W41, dtype: int64
#
# AVGFAM_W41
# Get worse              1105
# Stay about the same     900
# Get better              509
# Refused                  10
# Name: AVGFAM_W41, dtype: int64
#
# HAPPENa_W41
# The U.S. economy will be WEAKER      1340
# The U.S. economy will be STRONGER     979
# Refused                               205
# Name: HAPPENa_W41, dtype: int64
#
# HAPPENb_W41
# Health care will be LESS affordable    1432
# Health care will be MORE affordable     886
# Refused                                 206
# Name: HAPPENb_W41, dtype: int64
#
# HAPPENc_W41
# Race relations will IMPROVE      1280
# Race relations will GET WORSE    1028
# Refused                           216
# Name: HAPPENc_W41, dtype: int64
#
# HAPPENd_W41
# The U.S. will be LESS important in the world    1515
# The U.S. will be MORE important in the world     781
# Refused                                          228
# Name: HAPPENd_W41, dtype: int64
#
# HAPPENe_W41
# The gap between the rich and the poor will GROW           1855
# The gap between the rich and the poor will GET SMALLER     485
# Refused                                                    184
# Name: HAPPENe_W41, dtype: int64
#
# HAPPENf_W41
# The public education system will GET WORSE    1310
# The public education system will IMPROVE       984
# Refused                                        230
# Name: HAPPENf_W41, dtype: int64
#
# HAPPENg_W41
# Religion will become LESS important                 1237
# Religion will be ABOUT AS important as it is now    1072
# Refused                                              215
# Name: HAPPENg_W41, dtype: int64
#
# HAPPENhF1_W41
# People 65 and older will have a WORSE standard of living     732
# People 65 and older will have a BETTER standard of living    415
# Refused                                                      102
# Name: HAPPENhF1_W41, dtype: int64
#
# HAPPENiF2_W41
# Children will have a WORSE standard of living     636
# Children will have a BETTER standard of living    532
# Refused                                           107
# Name: HAPPENiF2_W41, dtype: int64
#
# HAPPENj_W41
# The country will be MORE politically divided    1629
# The country will be LESS politically divided     684
# Refused                                          211
# Name: HAPPENj_W41, dtype: int64
#
# HAPPEN2a_W41
# Will probably happen          1220
# Will probably not happen       886
# Will definitely happen         298
# Will definitely not happen      91
# Refused                         29
# Name: HAPPEN2a_W41, dtype: int64
#
# HAPPEN2b_W41
# Will probably happen          1166
# Will probably not happen       754
# Will definitely happen         508
# Will definitely not happen      82
# Refused                         14
# Name: HAPPEN2b_W41, dtype: int64
#
# HAPPEN2c_W41
# Will probably happen          1276
# Will probably not happen       917
# Will definitely happen         213
# Will definitely not happen      98
# Refused                         20
# Name: HAPPEN2c_W41, dtype: int64
#
# HAPPEN2d_W41
# Will probably happen          1032
# Will probably not happen       979
# Will definitely happen         288
# Will definitely not happen     194
# Refused                         31
# Name: HAPPEN2d_W41, dtype: int64
#
# HAPPEN2e_W41
# Will probably happen          1441
# Will definitely happen         758
# Will probably not happen       266
# Will definitely not happen      47
# Refused                         12
# Name: HAPPEN2e_W41, dtype: int64
#
# HAPPEN2f_W41
# Will probably happen          1356
# Will probably not happen       718
# Will definitely happen         287
# Will definitely not happen     141
# Refused                         22
# Name: HAPPEN2f_W41, dtype: int64
#
# HAPPEN2g_W41
# Will probably happen          1260
# Will definitely happen         884
# Will probably not happen       308
# Will definitely not happen      64
# Refused                          8
# Name: HAPPEN2g_W41, dtype: int64
#
# HAPPEN2h_W41
# Will probably not happen      1314
# Will probably happen           809
# Will definitely not happen     208
# Will definitely happen         162
# Refused                         31
# Name: HAPPEN2h_W41, dtype: int64
#
# NATDEBT_W41
# Grow larger            1621
# Stay about the same     524
# Be reduced              323
# Be eliminated            45
# Refused                  11
# Name: NATDEBT_W41, dtype: int64
#
# ENVC_W41
# Worse than it is now           1454
# About the same as it is now     656
# Better than it is now           405
# Refused                           9
# Name: ENVC_W41, dtype: int64
#
# POPPROB_W41
# Major problem    1084
# Minor problem     972
# Not a problem     457
# Refused            11
# Name: POPPROB_W41, dtype: int64
#
# FTRWORRYa_W41
# Fairly worried        1208
# Very worried           660
# Not too worried        575
# Not at all worried      68
# Refused                 13
# Name: FTRWORRYa_W41, dtype: int64
#
# FTRWORRYb_W41
# Fairly worried        1003
# Very worried           965
# Not too worried        463
# Not at all worried      84
# Refused                  9
# Name: FTRWORRYb_W41, dtype: int64
#
# FTRWORRYc_W41
# Very worried          1272
# Fairly worried         926
# Not too worried        274
# Not at all worried      39
# Refused                 13
# Name: FTRWORRYc_W41, dtype: int64
#
# FTRWORRYd_W41
# Very worried          1224
# Fairly worried         998
# Not too worried        253
# Not at all worried      41
# Refused                  8
# Name: FTRWORRYd_W41, dtype: int64
#
# FTRWORRYe_W41
# Very worried          1087
# Fairly worried         883
# Not too worried        455
# Not at all worried      96
# Refused                  3
# Name: FTRWORRYe_W41, dtype: int64
#
# FTRWORRYf_W41
# Very worried          1048
# Fairly worried         683
# Not too worried        534
# Not at all worried     250
# Refused                  9
# Name: FTRWORRYf_W41, dtype: int64
#
# ELDCARE_W41
# LESS prepared financially for retirement than older adults today          1848
# BETTER prepared financially for retirement than older adults are today     658
# Refused                                                                     18
# Name: ELDCARE_W41, dtype: int64
#
# ELDFINANCEF1_W41
# Older Americans themselves    465
# Family members                442
# Government                    331
# Refused                        11
# Name: ELDFINANCEF1_W41, dtype: int64
#
# ELDFINANCEF2_W41
# Government                    679
# Older Americans themselves    364
# Family members                201
# Refused                        31
# Name: ELDFINANCEF2_W41, dtype: int64
#
# GOVPRIOa_W41
# A top priority                          1218
# An important, but not a top priority    1060
# A lower priority                         211
# Should not be done                        21
# Refused                                   14
# Name: GOVPRIOa_W41, dtype: int64
#
# GOVPRIOb_W41
# A top priority                          1353
# An important, but not a top priority     856
# A lower priority                         207
# Should not be done                        99
# Refused                                    9
# Name: GOVPRIOb_W41, dtype: int64
#
# GOVPRIOc_W41
# A top priority                          1711
# An important, but not a top priority     533
# A lower priority                         156
# Should not be done                       119
# Refused                                    5
# Name: GOVPRIOc_W41, dtype: int64
#
# GOVPRIOd_W41
# An important, but not a top priority    1232
# A top priority                           830
# A lower priority                         395
# Should not be done                        57
# Refused                                   10
# Name: GOVPRIOd_W41, dtype: int64
#
# GOVPRIOe_W41
# A top priority                          1089
# An important, but not a top priority     914
# A lower priority                         374
# Should not be done                       132
# Refused                                   15
# Name: GOVPRIOe_W41, dtype: int64
#
# GOVPRIOfF1_W41
# An important, but not a top priority    398
# Should not be done                      295
# A top priority                          281
# A lower priority                        269
# Refused                                   6
# Name: GOVPRIOfF1_W41, dtype: int64
#
# GOVPRIOgF1_W41
# A top priority                          462
# An important, but not a top priority    360
# A lower priority                        315
# Should not be done                      107
# Refused                                   5
# Name: GOVPRIOgF1_W41, dtype: int64
#
# GOVPRIOhF1_W41
# Should not be done                      514
# An important, but not a top priority    290
# A lower priority                        221
# A top priority                          218
# Refused                                   6
# Name: GOVPRIOhF1_W41, dtype: int64
#
# GOVPRIOiF1_W41
# An important, but not a top priority    633
# A top priority                          458
# A lower priority                        147
# Should not be done                       11
# Name: GOVPRIOiF1_W41, dtype: int64
#
# GOVPRIOjF1_W41
# A top priority                          481
# An important, but not a top priority    468
# A lower priority                        208
# Should not be done                       92
# Name: GOVPRIOjF1_W41, dtype: int64
#
# GOVPRIOkF2_W41
# An important, but not a top priority    497
# A top priority                          306
# A lower priority                        271
# Should not be done                      192
# Refused                                   9
# Name: GOVPRIOkF2_W41, dtype: int64
#
# GOVPRIOlF2_W41
# An important, but not a top priority    517
# A lower priority                        413
# A top priority                          195
# Should not be done                      145
# Refused                                   5
# Name: GOVPRIOlF2_W41, dtype: int64
#
# GOVPRIOmF2_W41
# A top priority                          595
# An important, but not a top priority    490
# A lower priority                        135
# Should not be done                       45
# Refused                                  10
# Name: GOVPRIOmF2_W41, dtype: int64
#
# GOVPRIOnF2_W41
# Should not be done                      490
# An important, but not a top priority    365
# A lower priority                        238
# A top priority                          174
# Refused                                   8
# Name: GOVPRIOnF2_W41, dtype: int64
#
# GOVPRIOoF2_W41
# A top priority                          614
# An important, but not a top priority    340
# A lower priority                        226
# Should not be done                       91
# Refused                                   4
# Name: GOVPRIOoF2_W41, dtype: int64
#
# GNATPROB_W41
# That the government will do too little to solve problems facing the country                               1513
# That the government will be too involved in problems that should be left to businesses and individuals     992
# Refused                                                                                                     19
# Name: GNATPROB_W41, dtype: int64
#
# WRKTRN1F1_W41
# The education system      490
# Individuals themselves    489
# Employers                 152
# Government                115
# Refused                     3
# Name: WRKTRN1F1_W41, dtype: int64
#
# WRKTRN1F2_W41
# The education system      679
# Individuals themselves    427
# Government                100
# Employers                  61
# Refused                     8
# Name: WRKTRN1F2_W41, dtype: int64
#
# WRKTRN2F1_W41
# The education system      428
# Individuals themselves    377
# Employers                 301
# Government                138
# Refused                     2
# Name: WRKTRN2F1_W41, dtype: int64
#
# WRKTRN2F2_W41
# Individuals themselves    456
# The education system      418
# Employers                 216
# Government                169
# Refused                     8
# Name: WRKTRN2F2_W41, dtype: int64
#
# JOBSECURITY_W41
# Less job security    1245
# About the same        929
# More job security     328
# Refused                22
# Name: JOBSECURITY_W41, dtype: int64
#
# JOBBENEFITS_W41
# Not as good as they are now       1038
# About the same as they are now     902
# Better than they are now           567
# Refused                             17
# Name: JOBBENEFITS_W41, dtype: int64
#
# AUTOWKPLC_W41
# Mostly hurt American workers      1245
# Neither helped nor hurt            709
# Mostly helped American workers     545
# Refused                             25
# Name: AUTOWKPLC_W41, dtype: int64
#
# ROBWRK_W41
# Probably happen          1342
# Definitely happen         735
# Probably not happen       411
# Definitely not happen      30
# Refused                     6
# Name: ROBWRK_W41, dtype: int64
#
# ROBWRK2_W41
# A somewhat bad thing for the country     835
# A very bad thing for the country         575
# A somewhat good thing for the country    533
# A very good thing for the country        125
# Refused                                    9
# Name: ROBWRK2_W41, dtype: int64
#
# AUTOLKLY_W41
# Probably not happen      580
# Probably happen          384
# Definitely not happen    368
# Definitely happen        162
# Refused                    5
# Name: AUTOLKLY_W41, dtype: int64
#
# ROBIMPACTa_W41
# Yes, likely       1896
# No, not likely     595
# Refused             33
# Name: ROBIMPACTa_W41, dtype: int64
#
# ROBIMPACTb_W41
# No, not likely    1672
# Yes, likely        824
# Refused             28
# Name: ROBIMPACTb_W41, dtype: int64
#
# LEGALIMG_W41
# Maintained at current levels    1265
# Increased                        676
# Decreased                        555
# Refused                           28
# Name: LEGALIMG_W41, dtype: int64
#
# FUTRCLASSa_W41
# Stay about the same    1095
# Increase                849
# Decrease                567
# Refused                  13
# Name: FUTRCLASSa_W41, dtype: int64
#
# FUTRCLASSb_W41
# Decrease               1152
# Increase                693
# Stay about the same     663
# Refused                  16
# Name: FUTRCLASSb_W41, dtype: int64
#
# FUTRCLASSc_W41
# Increase               1582
# Stay about the same     505
# Decrease                423
# Refused                  14
# Name: FUTRCLASSc_W41, dtype: int64
#
# HARASS1F1a_W41
# Major problem    554
# Minor problem    540
# Not a problem    148
# Refused            7
# Name: HARASS1F1a_W41, dtype: int64
#
# HARASS1F1b_W41
# Major problem    590
# Minor problem    476
# Not a problem    177
# Refused            6
# Name: HARASS1F1b_W41, dtype: int64
#
# HARASS1F1c_W41
# Major problem    798
# Minor problem    377
# Not a problem     69
# Refused            5
# Name: HARASS1F1c_W41, dtype: int64
#
# HARASS1F1d_W41
# Major problem    737
# Minor problem    413
# Not a problem     93
# Refused            6
# Name: HARASS1F1d_W41, dtype: int64
#
# HARASS1NOWRKF2a_W41
# Major problem    583
# Minor problem    559
# Not a problem    131
# Refused            2
# Name: HARASS1NOWRKF2a_W41, dtype: int64
#
# HARASS1NOWRKF2c_W41
# Major problem    866
# Minor problem    350
# Not a problem     53
# Refused            6
# Name: HARASS1NOWRKF2c_W41, dtype: int64
#
# HARASS1NOWRKF2d_W41
# Major problem    760
# Minor problem    400
# Not a problem    106
# Refused            9
# Name: HARASS1NOWRKF2d_W41, dtype: int64
#
# HARASS3F1_W41
# Has made it harder for men     686
# Hasn't made much difference    397
# Has made it easier for men     158
# Refused                          8
# Name: HARASS3F1_W41, dtype: int64
#
# HARASS3NOWRKF2_W41
# Has made it harder for men     692
# Hasn't made much difference    417
# Has made it easier for men     157
# Refused                          9
# Name: HARASS3NOWRKF2_W41, dtype: int64
#
# HARASS4_W41
# Yes        1348
# No         1163
# Refused      13
# Name: HARASS4_W41, dtype: int64
#
# HARASS5_W41
# Both                                         691
# Outside of a professional or work setting    461
# In a professional or work setting            192
# Refused                                        4
# Name: HARASS5_W41, dtype: int64
#
# ETHNCMAJMOD_W41
# Neither a good nor bad thing    1057
# A very good thing                448
# A somewhat good thing            438
# A somewhat bad thing             381
# A very bad thing                 180
# Refused                           20
# Name: ETHNCMAJMOD_W41, dtype: int64
#
# ETHNCMAJ3_W41
# More conflicts between racial and ethnic groups     1227
# Fewer conflicts between racial and ethnic groups     685
# Not much of an impact                                585
# Refused                                               27
# Name: ETHNCMAJ3_W41, dtype: int64
#
# ETHNCMAJ4_W41
# Weaken American customs and values        976
# Not much of an impact                     765
# Strengthen American customs and values    746
# Refused                                    37
# Name: ETHNCMAJ4_W41, dtype: int64
#
# AGEMAJ_W41
# A somewhat bad thing            1084
# Neither a good nor bad thing     686
# A somewhat good thing            342
# A very bad thing                 302
# A very good thing                 93
# Refused                           17
# Name: AGEMAJ_W41, dtype: int64
#
# INTRMAR_W41
# Neither a good nor bad thing    997
# A very good thing               738
# A somewhat good thing           489
# A somewhat bad thing            194
# A very bad thing                 90
# Refused                          16
# Name: INTRMAR_W41, dtype: int64
#
# SSMONEY_W41
# No                            762
# Yes, but at reduced levels    740
# Yes, at current levels        279
# Refused                        15
# Name: SSMONEY_W41, dtype: int64
#
# SSCUT_W41
# Social Security benefits should not be reduced in any way               1885
# Some reductions in benefits for future retirees will need to be made     620
# Refused                                                                   19
# Name: SSCUT_W41, dtype: int64
#
# FUTR_ABR_W41
# Legal but with some restrictions    1402
# Legal with no restrictions           568
# Illegal except in certain cases      384
# Illegal with no exceptions           135
# Refused                               35
# Name: FUTR_ABR_W41, dtype: int64
#
# FUTR_DIV_W41
# About as likely to get divorced as people are now    1532
# More likely to get divorced than people are now       685
# Less likely to get divorced than people are now       283
# Refused                                                24
# Name: FUTR_DIV_W41, dtype: int64
#
# FUTR_M_W41
# Less likely to get married than people are now      1340
# About as likely to get married as people are now    1003
# More likely to get married than people are now       163
# Refused                                               18
# Name: FUTR_M_W41, dtype: int64
#
# FUTR_K_W41
# Less likely to have children than people are now      1172
# About as likely to have children as people are now    1115
# More likely to have children than people are now       217
# Refused                                                 20
# Name: FUTR_K_W41, dtype: int64
#
# SOLVPROBa_W41
# A somewhat positive impact    1135
# A very positive impact        1078
# A somewhat negative impact     210
# A very negative impact          65
# Refused                         36
# Name: SOLVPROBa_W41, dtype: int64
#
# SOLVPROBb_W41
# A somewhat positive impact    1105
# A somewhat negative impact     813
# A very negative impact         374
# A very positive impact         196
# Refused                         36
# Name: SOLVPROBb_W41, dtype: int64
#
# SOLVPROBc_W41
# A somewhat positive impact    1134
# A somewhat negative impact     646
# A very positive impact         373
# A very negative impact         328
# Refused                         43
# Name: SOLVPROBc_W41, dtype: int64
#
# SOLVPROBdF1_W41
# A somewhat positive impact    475
# A somewhat negative impact    461
# A very negative impact        228
# A very positive impact         73
# Refused                        12
# Name: SOLVPROBdF1_W41, dtype: int64
#
# SOLVPROBeF2_W41
# A somewhat positive impact    673
# A somewhat negative impact    358
# A very positive impact        129
# A very negative impact         91
# Refused                        24
# Name: SOLVPROBeF2_W41, dtype: int64
#
# SOLVPROBf_W41
# A somewhat positive impact    835
# A somewhat negative impact    776
# A very negative impact        650
# A very positive impact        231
# Refused                        32
# Name: SOLVPROBf_W41, dtype: int64
#
# SOLVPROBg_W41
# A somewhat positive impact    1306
# A very positive impact         529
# A somewhat negative impact     465
# A very negative impact         181
# Refused                         43
# Name: SOLVPROBg_W41, dtype: int64
#
# SOLVPROBh_W41
# A somewhat positive impact    1265
# A very positive impact         603
# A somewhat negative impact     398
# A very negative impact         223
# Refused                         35
# Name: SOLVPROBh_W41, dtype: int64
#
# SOLVPROBi_W41
# A somewhat positive impact    1347
# A very positive impact         615
# A somewhat negative impact     404
# A very negative impact         123
# Refused                         35
# Name: SOLVPROBi_W41, dtype: int64
#
# F_METRO
# Metropolitan        2148
# Non-metropolitan     376
# Name: F_METRO, dtype: int64
#
# F_CREGION
# South        949
# Midwest      616
# West         547
# Northeast    412
# Name: F_CREGION, dtype: int64
#
# F_AGECAT
# 30-49     816
# 50-64     753
# 65+       559
# 18-29     393
# DK/REF      3
# Name: F_AGECAT, dtype: int64
#
# F_SEX
# Female     1391
# Male       1131
# Refused       2
# Name: F_SEX, dtype: int64
#
# F_EDUCCAT
# H.S. graduate or less    945
# College graduate+        879
# Some College             695
# Don't know/Refused         5
# Name: F_EDUCCAT, dtype: int64
#
# F_EDUCCAT2
# High school graduate               759
# College graduate/some post grad    516
# Some college, no degree            491
# Postgraduate                       363
# Associate's degree                 204
# Less than high school              186
# Don't know/Refused                   5
# Name: F_EDUCCAT2, dtype: int64
#
# F_HISP
# No         2140
# Yes         375
# Refused       9
# Name: F_HISP, dtype: int64
#
# F_RACECMB
# White                        1877
# Black or African American     310
# Mixed Race                    114
# Or some other race            103
# Refused                        64
# Asian or Asian-American        56
# Name: F_RACECMB, dtype: int64
#
# F_RACETHN
# White non-Hispanic    1676
# Hispanic               375
# Black non-Hispanic     300
# Other                  142
# Refused                 31
# Name: F_RACETHN, dtype: int64
#
# F_NATIVITY
# U.S.                    2308
# Another country          198
# Puerto Rico               12
# Other U.S. territory       3
# Refused                    3
# Name: F_NATIVITY, dtype: int64
#
# F_CITIZEN
# Yes        2452
# No           68
# Refused       4
# Name: F_CITIZEN, dtype: int64
#
# F_MARITAL
# Married                  1219
# Never been married        532
# Divorced                  301
# Living with a partner     233
# Widowed                   172
# Separated                  58
# Refused                     9
# Name: F_MARITAL, dtype: int64
#
# F_RELIG
# Protestant (for example, Baptist, Methodist, Non-denominational, Lutheran, Presbyterian, Pentecostal, Episcopalian, Refo    1069
# Nothing in particular                                                                                                        463
# Roman Catholic                                                                                                               463
# Agnostic                                                                                                                     160
# Atheist                                                                                                                      160
# Something else, Specify                                                                                                       65
# Jewish                                                                                                                        52
# Mormon (Church of Jesus Christ of Latter-day Saints or LDS)                                                                   31
# Muslim                                                                                                                        16
# Refused                                                                                                                       14
# Hindu                                                                                                                         12
# Buddhist                                                                                                                      10
# Orthodox (such as Greek, Russian, or some other Orthodox church)                                                               9
# Name: F_RELIG, dtype: int64
#
# F_BORN
# No, not born-again or evangelical Christian    848
# Yes, born-again or evangelical Christian       699
# Refused                                         40
# Name: F_BORN, dtype: int64
#
# F_ATTEND
# Never                    684
# Seldom                   614
# Once a week              460
# A few times a year       381
# More than once a week    190
# Once or twice a month    182
# Refused                   13
# Name: F_ATTEND, dtype: int64
#
# F_PARTY_FINAL
# Democrat          915
# Republican        681
# Independent       604
# Something else    294
# Refused            30
# Name: F_PARTY_FINAL, dtype: int64
#
# F_PARTYLN_FINAL
# The Democratic Party    444
# The Republican Party    358
# Refused                 126
# Name: F_PARTYLN_FINAL, dtype: int64
#
# F_PARTYSUM_FINAL
# Dem/Lean Dem          1359
#  Rep/Lean Rep         1039
# DK/Refused/No lean     126
# Name: F_PARTYSUM_FINAL, dtype: int64
#
# F_INCOME
# $50,000 to less than $75,000      435
# $100,000 to less than $150,000    279
# $75,000 to less than $100,000     273
# $10,000 to less than $20,000      254
# $20,000 to less than $30,000      253
# $40,000 to less than $50,000      249
# $30,000 to less than $40,000      247
# $150,000 or more                  220
# Less than $10,000                 203
# Refused                           111
# Name: F_INCOME, dtype: int64
#
# F_INCOME_RECODE
# $30-$74,999           931
# $75,000+              772
# <$30,000              710
# Don't know/Refused    111
# Name: F_INCOME_RECODE, dtype: int64
#
# F_REG
# You are ABSOLUTELY CERTAIN that you are registered to vote at your current address    1907
# You are NOT registered to vote at your current address                                 363
# You are PROBABLY registered, but there is a chance your registration has lapsed        177
# Refused                                                                                  5
# Name: F_REG, dtype: int64
#
# F_IDEO
# Moderate             977
# Conservative         575
# Liberal              480
# Very liberal         214
# Very conservative    206
# Refused               72
# Name: F_IDEO, dtype: int64
#
# F_INTUSER
# Internet User        2350
# Non Internet User     174
# Name: F_INTUSER, dtype: int64
#
# F_VOLSUM
# No         1592
# Yes         927
# Refused       5
# Name: F_VOLSUM, dtype: int64
#
# WEIGHT_W41
# 4.509111    26
# 0.094035    25
# 1.475355     3
# 1.057068     3
# 0.464919     3
#             ..
# 2.352194     1
# 2.481482     1
# 0.859783     1
# 1.037618     1
# 0.423838     1
# Name: WEIGHT_W41, Length: 2402, dtype: int64

# %%
target = "OPTIMIST_W41"
